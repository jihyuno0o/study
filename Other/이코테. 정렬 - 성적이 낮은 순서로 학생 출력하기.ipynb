# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
grades = []
for i in range(n):
    data = input().split()
    grades.append([data[0], int(data[1])])

# list[1]을 기준으로 오름차순 정렬
for grade in sorted(grades, key = lambda x : x[1]):
    print(grade[0], end=' ')
# Out:
# 2
# 홍길동 95
# 이순신 77
# 이순신 홍길동

# %% [markdown]
# 책 답

# %%
n = int(input())
array = []
for i in range(n):
    input_data = input().split()
    array.append((input_data[0], int(input_data[1])))

array = sorted(array, key = lambda student: student[1])

for student in array:
    print(student[0], end=' ')
# Out:
# 2
# 홍길동 95
# 이순신 77
# 이순신 홍길동
