# %% [markdown]
# https://programmers.co.kr/learn/courses/30/lessons/49994

# %% [markdown]
# 게임 캐릭터를 4가지 명령어를 통해 움직이려 합니다. 명령어는 다음과 같습니다.
#
# - U: 위쪽으로 한 칸 가기
#
# - D: 아래쪽으로 한 칸 가기
#
# - R: 오른쪽으로 한 칸 가기
#
# - L: 왼쪽으로 한 칸 가기
#
# 캐릭터는 좌표평면의 (0, 0) 위치에서 시작합니다. 좌표평면의 경계는 왼쪽 위(-5, 5), 왼쪽 아래(-5, -5), 오른쪽 위(5, 5), 오른쪽 아래(5, -5)로 이루어져 있습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 이때, 우리는 게임 캐릭터가 지나간 길 중 캐릭터가 처음 걸어본 길의 길이를 구하려고 합니다. 예를 들어 위의 예시에서 게임 캐릭터가 움직인 길이는 9이지만, 캐릭터가 처음 걸어본 길의 길이는 7이 됩니다. (8, 9번 명령어에서 움직인 길은 2, 3번 명령어에서 이미 거쳐 간 길입니다)
#
# 단, 좌표평면의 경계를 넘어가는 명령어는 무시합니다.

# %% [markdown]
# 명령어가 매개변수 dirs로 주어질 때, 게임 캐릭터가 처음 걸어본 길의 길이를 구하여 return 하는 solution 함수를 완성해 주세요.

# %% [markdown]
# 제한사항
# - dirs는 string형으로 주어지며, 'U', 'D', 'R', 'L' 이외에 문자는 주어지지 않습니다.
# - dirs의 길이는 500 이하의 자연수입니다.

# %%
dirs = "ULURRDLLU"
# 7

# %%
dirs = "LULLLLLLU"
# 7

# %%
p = [0,0] # [x,y]

# %%
path = set() #(cur_x, cur_y, next_x, next_y)

# %%
for d in dirs:
    if d == "U" and p[1] < 5:
        path.add((p[0], p[1], p[0], p[1]+1))
        path.add((p[0], p[1]+1, p[0], p[1]))
        p[1] += 1
        
    elif d == "D" and p[1] > -5:
        path.add((p[0], p[1], p[0], p[1]-1))
        path.add((p[0], p[1]-1, p[0], p[1]))
        p[1] -= 1
        
    elif d == "R" and p[0] < 5:
        path.add((p[0], p[1], p[0]+1, p[1]))
        path.add((p[0]+1, p[1], p[0], p[1]))
        p[0] += 1
        
    elif d == "L" and p[0] > -5:
        path.add((p[0], p[1], p[0]-1, p[1]))
        path.add((p[0]-1, p[1], p[0], p[1]))
        p[0] -= 1

# %%
len(path)
# Out:
# 14

# %% [markdown]
# solution

# %%
def solution(dirs):
    p = [0,0] # [x,y]
    path = set() #(cur_x, cur_y, next_x, next_y)
    for d in dirs:
        if d == "U" and p[1] < 5:
            path.add((p[0], p[1], p[0], p[1]+1))
            path.add((p[0], p[1]+1, p[0], p[1]))
            p[1] += 1

        elif d == "D" and p[1] > -5:
            path.add((p[0], p[1], p[0], p[1]-1))
            path.add((p[0], p[1]-1, p[0], p[1]))
            p[1] -= 1

        elif d == "R" and p[0] < 5:
            path.add((p[0], p[1], p[0]+1, p[1]))
            path.add((p[0]+1, p[1], p[0], p[1]))
            p[0] += 1

        elif d == "L" and p[0] > -5:
            path.add((p[0], p[1], p[0]-1, p[1]))
            path.add((p[0]-1, p[1], p[0], p[1]))
            p[0] -= 1
    
    return len(path) // 2

# %% [markdown]
# 다른 사람 코드

# %%
def solution(dirs):
    s = set()
    d = {'U': (0,1), 'D': (0, -1), 'R': (1, 0), 'L': (-1, 0)}
    x, y = 0, 0
    for i in dirs:
        nx, ny = x + d[i][0], y + d[i][1]
        if -5 <= nx <= 5 and -5 <= ny <= 5:
            s.add((x,y,nx,ny))
            s.add((nx,ny,x,y))
            x, y = nx, ny
    return len(s)//2
